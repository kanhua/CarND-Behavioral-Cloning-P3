# %%
# %matplotlib inline
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
hist=pickle.load(open("model_hist_r_v14.p",'rb'))

# %%
hist
# Out:
# {'loss': [0.16799933469436698,
#   0.078401047391738185,
#   0.10902865625325395,
#   0.066014223650173481,
#   0.09140188036432928,
#   0.058197792457848431,
#   0.084872611374318493,
#   0.054315334260211581,
#   0.077208600275710151,
#   0.052660381923573071],
#  'val_loss': [0.058744831466745133,
#   0.054558964814320425,
#   0.068861910045850239,
#   0.041031847606278447,
#   0.05529705950424383,
#   0.040076160589150624,
#   0.052254357235094084,
#   0.037874450044470202,
#   0.043475340733134291,
#   0.03432894439867816]}

# %%
plt.plot(hist['loss'],'o-',label="training loss")
plt.plot(hist['val_loss'],'o-',label="validation loss")
plt.ylabel("MSE")
plt.xlabel("epoch")
plt.legend()
plt.savefig("./data_figs/mse_loss.png")
